# %%
# Importar las librerías
import pandas as pd
import matplotlib.pyplot as plt

# Verificar Pandas
print("Pandas instalado correctamente. Versión:", pd.__version__)

# Verificar Matplotlib con un gráfico básico
plt.plot([1, 2, 3], [4, 5, 6])
plt.title("Prueba Matplotlib")
plt.show()
# Out:
# Pandas instalado correctamente. Versión: 2.2.2

# %%
# Importar las librerías
import pandas as pd
import matplotlib.pyplot as plt

# Verificar Pandas
print("Pandas instalado correctamente. Versión:", pd.__version__)

# Verificar Matplotlib con un gráfico básico
plt.plot([1, 2, 3], [4, 5, 6])
plt.title("Prueba Matplotlib")
plt.show()
# Out:
# Pandas instalado correctamente. Versión: 2.2.2
